# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd

# %% [markdown]
# ### Explore the data

# %%
df = pd.read_csv("synthetic_sample_data.csv")
df
# Out:
#      Unnamed: 0   Movie Id            Genre Release Date    Rating  \
# 0            44  TOYHANVUR           Horror   07/07/1985  9.750176
# 1            47  CORCILSLF      Documentary   05/08/1999  7.912876
# 2            64  UBWUVIHEL        Adventure   08/05/1996  3.116053
# 3            67  CGHMHKJHH          Fantasy   21/07/2018  8.811783
# 4            67  WMLWHTAMN          Fantasy   28/10/2011  5.250991
# ..          ...        ...              ...          ...       ...
# 995          79  FLGKFVWQC            Crime   03/03/2019  9.289647
# 996          41  YPFAOWQTB           Action   26/09/1984  8.779748
# 997          17  PFOLXESPH            Drama   13/07/2014  3.418956
# 998          80  IOENWBYUW          Fantasy   05/12/2004  9.090440
# 999          43  LMZTDBXMY  Science Fiction   12/05/1998  7.430801
#
#                                                Summary Shooting Location  \
# 0    A group of college students get more than they...          New York
# ...

# %%
empty_rate = {}
for column_name in df.columns:
    empty_rate[column_name] = sum(pd.isnull(df[column_name]))

empty_rate
# Out:
# {'Unnamed: 0': 0,
#  'Movie Id': 0,
#  'Genre': 0,
#  'Release Date': 0,
#  'Rating': 0,
#  'Summary': 0,
#  'Shooting Location': 0,
#  'Budget in USD': 20,
#  'Awards': 0,
#  'Popular': 0}

# %%
df[pd.isnull(df["Budget in USD"])]
# Out:
#      Unnamed: 0   Movie Id            Genre Release Date    Rating  \
# 52           28  JDIKIDDGY            Drama   17/12/1991  9.901920
# 59           38  ZCKFMPWZL          Musical   13/01/2006  4.496297
# 65           31  QKPWRHWCW        Adventure   14/12/1986  9.034368
# 118          77  RBUVAOLXJ           Sports   26/08/2006  9.781337
# 133          82  SHWNLGZNU            Drama   29/04/1995  7.900184
# 144          36  HSELIBSUI          Mystery   15/03/1984  9.924358
# 176          52  KRNDDCERL         Thriller   25/11/2014  9.448966
# 282          53  PERNNBIJB        Animation   29/10/2008  8.476273
# 333          28  YHZKCSHGI            Drama   03/11/2018  5.828396
# 360          64  TFCQUJXPV        Adventure   04/02/1983  8.971272
# 413          94  TQICNAYOM          Mystery   11/04/2001  8.490931
# 481          91  PTBNNYJAZ        Adventure   05/03/2005  8.755281
# 487           9  MDTSJQLOG           Comedy   26/05/2020  9.380835
# ...
